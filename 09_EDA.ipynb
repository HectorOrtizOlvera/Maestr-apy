# %% [markdown]
# <a href="https://colab.research.google.com/github/HectorOrtizOlvera/Maestr-apy/blob/main/09_EDA.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install numpy==1.26.4
# !pip install sweetviz --upgrade
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 61.0/61.0 kB 2.0 MB/s eta 0:00:00
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 18.0/18.0 MB 83.6 MB/s eta 0:00:00
# ...
#   Attempting uninstall: numpy
#     Found existing installation: numpy 2.0.2
#     Uninstalling numpy-2.0.2:
#       Successfully uninstalled numpy-2.0.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# opencv-python-headless 4.12.0.88 requires numpy<2.3.0,>=2; python_version >= "3.9", but you have numpy 1.26.4 which is incompatible.
# shap 0.50.0 requires numpy>=2, but you have numpy 1.26.4 which is incompatible.
# jaxlib 0.7.2 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# pytensor 2.35.1 requires numpy>=2.0, but you have numpy 1.26.4 which is incompatible.
# ...

# %%
# Import Sweetviz library
import sweetviz

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns
sns.set(style="ticks", context="talk")
plt.style.use("dark_background")

# %%
# Mount your google drive
from google.colab import drive
drive.mount("/drive")
save_path = '/drive/My Drive/sweetviz/'
# Out:
# Drive already mounted at /drive; to attempt to forcibly remount, call drive.mount("/drive", force_remount=True).

# %% [markdown]
# UFO

# %%
ufo = pd.read_csv('https://raw.githubusercontent.com/IEXE-Tec/analisis-descriptivo/master/ufo.csv')
ufo.head()
# Out:
# /tmp/ipython-input-1454972696.py:1: DtypeWarning: Columns (5,9) have mixed types. Specify dtype option on import or set low_memory=False.
#   ufo = pd.read_csv('https://raw.githubusercontent.com/IEXE-Tec/analisis-descriptivo/master/ufo.csv')
#            datetime                  city state country     shape  \
# 0  10/10/1949 20:30            san marcos    tx      us  cylinder
# 1  10/10/1949 21:00          lackland afb    tx     NaN     light
# 2  10/10/1955 17:00  chester (uk/england)   NaN      gb    circle
# 3  10/10/1956 21:00                  edna    tx      us    circle
# 4  10/10/1960 20:00               kaneohe    hi      us     light
#
#   duration (seconds) duration (hours/min)  \
# 0               2700           45 minutes
# 1               7200              1-2 hrs
# 2                 20           20 seconds
# 3                 20             1/2 hour
# 4                900           15 minutes
#
# ...

# %%
ufo.columns
# Out:
# Index(['datetime', 'city', 'state', 'country', 'shape', 'duration (seconds)',
#        'duration (hours/min)', 'comments', 'date posted', 'latitude',
#        'longitude '],
#       dtype='object')

# %%
ufo.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 80332 entries, 0 to 80331
# Data columns (total 11 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   datetime              80332 non-null  object
#  1   city                  80332 non-null  object
#  2   state                 74535 non-null  object
#  3   country               70662 non-null  object
#  4   shape                 78400 non-null  object
#  5   duration (seconds)    80332 non-null  object
#  6   duration (hours/min)  80332 non-null  object
#  7   comments              80317 non-null  object
#  8   date posted           80332 non-null  object
#  9   latitude              80332 non-null  object
#  10  longitude             80332 non-null  float64
# dtypes: float64(1), object(10)
# memory usage: 6.7+ MB

# %%
ufo.describe()
# Out:
#          longitude
# count  80332.000000
# mean     -86.772885
# std       39.697205
# min     -176.658056
# 25%     -112.073333
# 50%      -87.903611
# 75%      -78.755000
# max      178.441900

# %%
ufo.rename(columns={
   'longitude ':'longitude',
   'duration (seconds)':'seconds',
       'duration (hours/min)':'hours_minutes'
},
inplace=True)
ufo.columns
# Out:
# Index(['datetime', 'city', 'state', 'country', 'shape', 'seconds',
#        'hours_minutes', 'comments', 'date posted', 'latitude', 'longitude'],
#       dtype='object')

# %% [markdown]
# Econtraras un error al momento de tratar de convertir ciertas columnas a sus tipos correspondientes. Los siguientes bloques de codigo, te ayudaran a limpiarla.

# %%
ufo['latitude'] = ufo['latitude'].astype(float)

# %%
ufo['latitude'] = ufo['latitude'].apply(lambda x: str(x).replace('q', ''))
ufo['latitude'] = ufo['latitude'].astype(float)

# %%
ufo['seconds'].astype(float)
# Out:
# 0        2700.0
# 1        7200.0
# 2          20.0
# 3          20.0
# 4         900.0
#           ...
# 80327     600.0
# 80328    1200.0
# 80329    1200.0
# 80330       5.0
# 80331    1020.0
# Name: seconds, Length: 80332, dtype: float64

# %%
ufo['seconds'] = ufo['seconds'].apply(lambda x: str(x).replace('`',''))
ufo['seconds'] = ufo['seconds'].astype(float)

# %%
ufo.describe()
# Out:
#             seconds      latitude     longitude
# count  8.033200e+04  80332.000000  80332.000000
# mean   9.016889e+03     38.124416    -86.772885
# std    6.202168e+05     10.469585     39.697205
# min    1.000000e-03    -82.862752   -176.658056
# 25%    3.000000e+01     34.134722   -112.073333
# 50%    1.800000e+02     39.411111    -87.903611
# 75%    6.000000e+02     42.788333    -78.755000
# max    9.783600e+07     72.700000    178.441900

# %% [markdown]
# # Sweetviz for UFO

# %%
import os
if not os.path.exists(save_path):
    os.makedirs(save_path)

ufo_viz = sweetviz.analyze(ufo)
ufo_viz.show_html(save_path + "ufo.html")
# Out:
#                                              |          | [  0%]   00:00 -> (? left)
# Report /drive/My Drive/sweetviz/ufo.html was generated! NOTEBOOK/COLAB USERS: the web browser MAY not pop up, regardless, the report IS saved in your notebook/colab files.
